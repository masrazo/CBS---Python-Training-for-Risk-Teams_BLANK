# %% [markdown]
# <center>
#     <img src="https://rockborne.com/wp-content/uploads/2021/07/LandingPage-Header-RED-CENTRE.jpg" width="900" alt="logo"  />
# </center>

# %% [markdown]
# # Practical: Exploratory Data Analysis
#
# *Session 3 · Notebook 06 · Practical · Student version*

# %% [markdown]
# ## About this notebook
#
# Practise the EDA workflow from the 03_02 walkthrough. You will warm up on the **Titanic** dataset, then run a fuller exploration of the **Superstore** sales dataset to draw out business insights.

# %% [markdown]
# ## About the exercises
#
# Each exercise is made of three cells:
#
# 1. **The question** (a markdown cell like this one).
# 2. **`# Your turn`**: an empty code cell for you to attempt the solution.
# 3. **`# Coach answer`**: the worked solution with correct code.
#
# Try each one yourself first. Later exercises reuse variables from earlier ones, so work in order.
#
# > **Coach note:** the answer cells have been removed. Fill in each `# Your turn` cell yourself.

# %% [markdown]
# ## About the data
#
# Both files live in the project [`../datasets/`](../datasets/) folder:
#
# - `train_titanic.csv`: passenger records (survival, class, sex, age, fare).
# - `superstore.csv`: retail orders (sales, profit, quantity, discount, category, region).

# %% [markdown]
# # Part 0: Setup and loading the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
## Loading data from S3:
from config import session_datasets

sns.set_theme(style='whitegrid')

##From S3: 
titanic = (
    spark.read.csv(
        session_datasets["train_titanic"],
        header=True,
        inferSchema=True
    )
).toPandas()

store = (
    spark.read.csv(
        session_datasets["superstore"],
        header=True,
        inferSchema=True,
        encoding="latin1"
    )
).toPandas()
print('titanic:', titanic.shape, '  store:', store.shape)

# %% [markdown]
# # Part 1: Warm-up on the Titanic data
#
# A few quick questions to re-use the walkthrough skills.

# %% [markdown]
# ### Scenario: What affected your chances of survival?
#
# You are investigating the 1912 Titanic disaster to work out which passengers were most likely to survive. Warm up with the guided questions below, then run your own open investigation in Exercise 1.4.

# %% [markdown]
# ### Exercise 1.1: First look
#
# Show the shape of `titanic` and a summary of its numeric columns.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 1.2: Survival rate by sex
#
# Compute the proportion of passengers who survived, split by `Sex`.
#
# > *Hint: `groupby('Sex')['Survived'].mean()`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 1.3: Distribution of age
#
# Draw a labelled histogram of passenger `Age`.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 1.4: Open investigation (Steps 1 and 2)
#
# **Step 1: explore seaborn.** Browse the seaborn API at <https://seaborn.pydata.org/api.html> and try a few plot types on the Titanic data to see what they look like.
#
# **Step: what affected survival?** Brainstorm and run your own analysis of which passengers were most likely to survive. Consider:
#
# - old vs young, and women vs men (and women and children vs men);
# - cheaper vs more expensive tickets;
# - passenger class and location on the ship.
#
# Use seaborn plots and pandas `groupby` to build visuals that answer the question. Try univariate plots (a violin of fare, a box of age) and multivariate ones (age by survival, fare by survival, age vs fare). There is no single right answer, so experiment.
#
# > *Hint: `sns.violinplot(data=titanic, x='Survived', y='Age')`, `sns.scatterplot(...)`, and `titanic.groupby('Sex')['Survived'].mean()` are good starting points.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# # Part 2: Exploring Superstore sales
#
# Now a fuller EDA on the Superstore data, following the univariate to multivariate spine.

# %% [markdown]
# ### Scenario: Optimising Sales and Profitability for a Retail Chain
#
# A national superstore wants to analyse its sales performance and identify opportunities to improve profitability. The dataset includes customer orders, sales figures, product categories, shipping details and profit margins.
#
# **Key insights we are looking for:**
#
# 1. **Sales trends and performance**
#    - Which product categories and sub-categories generate the highest revenue?
#    - Are there seasonal sales trends?
#    - How do sales vary by region and customer segment?
#
# 2. **Profitability analysis**
#    - Which products have the highest and lowest profit margins?
#    - Are there unprofitable items that should be discontinued?
#    - How do discounts impact overall profit?
#
# 3. **Customer behaviour and segmentation**
#    - What are the key characteristics of high-value customers?
#    - How do different customer segments contribute to sales?
#
# 4. **Shipping and logistics**
#    - Is shipping mode associated with profitability?
#    - Are certain regions associated with higher or lower profit?
#
# The exercises below work through the start of this investigation.

# %% [markdown]
# ### Superstore data dictionary
#
# | Column | Meaning |
# |---|---|
# | `Order Date` / `Ship Date` | When the order was placed / shipped |
# | `Ship Mode` | Shipping speed chosen |
# | `Segment` | Customer segment (Consumer, Corporate, Home Office) |
# | `Region` / `State` / `City` | Where the order was delivered |
# | `Category` / `Sub-Category` | Product grouping |
# | `Sales` | Revenue from the line |
# | `Quantity` | Units sold |
# | `Discount` | Discount applied (fraction) |
# | `Profit` | Profit from the line |

# %% [markdown]
# ### Exercise 2.1: First look
#
# Show the first few rows of `store`, its shape, and a summary of the numeric columns.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.2: Sales by category (groupby)
#
# Use `groupby` to find the **total Sales** for each `Category`, sorted from highest to lowest.
#
# > *Hint: `store.groupby('Category')['Sales'].sum()`, then `.sort_values(ascending=False)`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.3: Sales and profit by segment (groupby)
#
# For each customer `Segment`, compute the **total Sales** and **total Profit** in a single `groupby`.
#
# > *Hint: `groupby('Segment').agg(total_sales=('Sales','sum'), total_profit=('Profit','sum'))`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.4: Univariate analysis
#
# Two parts: (a) draw a labelled histogram of `Sales`; (b) show how many orders fall in each `Category`.
#
# > *Hint: `.hist()` for the distribution, `value_counts()` for the category counts.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.5: Bivariate analysis
#
# Two parts: (a) total `Sales` per `Region` as a bar chart; (b) a scatter of `Discount` against `Profit`.
#
# > *Hint: `groupby('Region')['Sales'].sum().plot(kind='bar')`, then `sns.scatterplot(...)`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.6: Multivariate analysis
#
# Draw a correlation heatmap of the numeric columns `Sales`, `Quantity`, `Discount` and `Profit`.
#
# > *Hint: Select the four columns, then `sns.heatmap(df.corr(), annot=True)`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.7: Loss-making sub-categories
#
# Discounts look related to profit. Compute the **total profit per Sub-Category** and identify which ones are loss-making (negative total profit). Write a sentence on what you found.
#
# > *Hint: `groupby('Sub-Category')['Profit'].sum().sort_values()`; the negative values sit at the top.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.8: Seasonal sales trend (line plot)
#
# Are there seasonal sales trends? Convert `Order Date` to a datetime, then plot **total Sales per month** as a line.
#
# > *Hint: `pd.to_datetime(store['Order Date'])`, then group by `.dt.to_period('M')` and sum `Sales`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.9: High-value customers
#
# Who are the high-value customers? Find the **top 10 customers** by total `Sales`.
#
# > *Hint: `groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.10: Shipping and logistics (subplots)
#
# Compare logistics two ways on a **single figure**. Use `plt.subplots` to show, side by side, (a) total `Profit` by `Ship Mode` and (b) total `Profit` by `Region`.
#
# > *Hint: `fig, axes = plt.subplots(1, 2, ...)`, then pass `ax=axes[0]` and `ax=axes[1]` to each plot.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.11: Composition with a pie chart
#
# Use a **pie chart** to show each `Region`'s share of total `Sales`. (Pie charts suit a few clear parts of a whole, as here.)
#
# > *Hint: `store.groupby('Region')['Sales'].sum()`, then `plt.pie(values, labels=..., autopct='%1.0f%%')`.*

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.12: Discover your own insight
#
# Everything so far has been guided. Now explore on your own: find **one insight that the earlier exercises did not cover**, and back it with a chart or table. Angles not yet explored include the profit **margin** (profit per dollar of sales) by category, total sales by `Sub-Category`, or how `Segment` and `Region` interact.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.13: Write your conclusions
#
# Bring it together. Looking back at the scenario's key insights and everything you have plotted, write **3 to 4 conclusions** a manager could act on. Back each one with a specific chart or table. Replace the text in the cell below with your conclusions.

# %% [markdown]
# _Write your conclusions here (replace this text)._

# %% [markdown]
# ## Further practice
#
# - Break the profit analysis down further by `Region` as well as `Sub-Category`.
# - Explore whether `Discount` relates to `Profit` within a single `Category`.
# - Write a short EDA summary: three insights a manager should act on.
