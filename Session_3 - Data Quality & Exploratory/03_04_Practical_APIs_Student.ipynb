# %% [markdown]
# <center>
#     <img src="https://rockborne.com/wp-content/uploads/2021/07/LandingPage-Header-RED-CENTRE.jpg" width="900" alt="logo"  />
# </center>

# %% [markdown]
# # Practical: Working with APIs
#
# *Session 3 · Notebook 04 · Practical · Student version*

# %% [markdown]
# ## About this notebook
#
# A mini-project to practise calling real web APIs. You will make requests, parse JSON, handle user input, and do light analysis and visualisation, building confidence to explore APIs on your own.

# %% [markdown]
# ## About the exercises
#
# Each exercise is made of three cells:
#
# 1. **The question** (a markdown cell like this one).
# 2. **`# Your turn`**: an empty code cell for you to attempt the solution.
# 3. **`# Coach answer`**: the worked solution with correct code.
#
# Try each one yourself first. Later exercises reuse functions from earlier ones, so work in order.
#
# > **Coach note:** this is the coach version, so every answer is filled in. The cells make live network calls, so they need an internet connection to run.

# %% [markdown]
# ## About the data
#
# Three free, **no-key** public APIs:
#
# - [Chuck Norris jokes](https://api.chucknorris.io/) (random jokes and categories).
# - [Open Brewery DB](https://www.openbrewerydb.org/documentation) (breweries by city and state).
# - [Disney API](https://disneyapi.dev/) (Disney characters).

# %% [markdown]
# # Part 0: Setup
#
# Install the packages if needed (`pip install requests pandas matplotlib`), import the libraries, and define one **reusable request helper** that every exercise will call.

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time

# %%
# Reusable API request function
def make_api_request(url, params=None):
    """Make a GET request to an API endpoint"""
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return None

# %% [markdown]
# # Part 1: Chuck Norris joke generator
#
# API docs: <https://api.chucknorris.io/>. Build a small set of functions on top of `make_api_request`.

# %% [markdown]
# ### Exercise 1.1: Fetch a random joke
#
# Write `get_random_joke()` that calls `https://api.chucknorris.io/jokes/random` and returns the joke text (the `value` field).

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 1.2: List the categories
#
# Write `get_categories()` that returns the list of joke categories from `/jokes/categories`.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 1.3: A joke from a category
#
# Write `get_joke_by_category(category)` that returns a random joke from a given category.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 1.4: Build a joke collection
#
# Write `build_joke_collection(num_jokes_per_category=2)` that gathers a few jokes from several categories into a dictionary. Add a small `time.sleep()` between calls to be polite to the API.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# # Part 2: Brewery explorer
#
# API docs: <https://www.openbrewerydb.org/documentation>. Note these functions pass query parameters with `params={...}` rather than building the URL by hand.

# %% [markdown]
# ### Exercise 2.1: Search by city
#
# Write `search_breweries_by_city(city)` returning breweries in a city (use `params={'by_city': city, 'per_page': 50}`).

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.2: Search by state
#
# Write `search_breweries_by_state(state)` returning breweries in a state.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.3: Analyse brewery types
#
# Write `analyze_brewery_types(state)` that loads the breweries into a DataFrame and shows the distribution of `brewery_type`.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.4: Create a brewery tour
#
# Write `create_brewery_tour(city, max_stops=5)` that lists up to `max_stops` breweries that have a street address.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 2.5: Visualise brewery types (bonus)
#
# Bonus: write `visualize_brewery_types(state)` that plots the counts of each brewery type.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# # Part 3: Disney character explorer
#
# API docs: <https://disneyapi.dev/>. This API paginates and returns characters with a list of films.

# %% [markdown]
# ### Exercise 3.1: Get characters (with pagination)
#
# Write `get_disney_characters(page=1, page_size=50)` that fetches characters using `params` for the page and page size.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 3.2: Search by name
#
# Write `search_character_by_name(name)` that searches for characters by name.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 3.3: Analyse character appearances
#
# Fetch a page of characters and count how many **films** each appears in. Show the top 10.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ### Exercise 3.4: Character statistics
#
# Using the DataFrame from 3.3, print the number of characters, the average number of films per character, and the name of the most-appearing character.

# %%
# Your turn. Write your solution here:

# %% [markdown]
# ---
#
# # Your Own Project
#
# Now it's your turn! Choose an API from the [Public APIs Repository](https://github.com/public-apis/public-apis) and create your own mini-project.
#
# ## Project Ideas:
#
# ### Beginner:
# - **Weather Dashboard**: Use wather APIs to create a weather comparison tool
# - **Dad Jokes Collection**: Use an API to build a joke database
# - **Random User Generator**: Create fake user profiles with the RandomUser API
#
# ### Intermediate:
# - **Recipe Finder**: Use Spoonacular or TheMealDB to search recipes by ingredients
# - **Movie Recommender**: Use TMDB API to recommend movies based on preferences
# - **Crypto Tracker**: Monitor cryptocurrency prices with CoinGecko API
#
# ### Advanced:
# - **News Aggregator**: Combine multiple news APIs to detect trending topics
# - **Music Analyzer**: Use Spotify API to analyze music trends and create playlists
# - **Travel Planner**: Combine weather, hotel, and attraction APIs

# %% [markdown]
# ## Common Issues & Solutions
#
# | Issue | Solution |
# |-------|----------|
# | "Connection Error" | Check internet connection, verify URL |
# | "401 Unauthorized" | Check if API needs authentication key |
# | "429 Too Many Requests" | Add delays between requests using `time.sleep()` |
# | Empty results | Check query parameters and API documentation |
# | KeyError | Print the full response first to understand structure |
#
# ## API Best Practices
#
# 1. **Always read the documentation** - Each API has its own rules and limitations
# 2. **Start small** - Test with one request before building loops
# 3. **Handle errors gracefully** - Use try/except blocks
# 4. **Respect rate limits** - Add delays between requests
# 5. **Cache responses** - Save data locally to avoid repeated API calls
# 6. **Never hardcode API keys** - Use environment variables
#
# ## Additional Resources
#
# - [Requests Documentation](https://docs.python-requests.org/)
# - [JSON in Python](https://realpython.com/python-json/)
# - [Public APIs List](https://github.com/public-apis/public-apis)
# - [Postman for API Testing](https://www.postman.com/)
# - [HTTP Status Codes](https://httpstatuses.com/)

# %% [markdown]
# ## Further practice
#
# - Add a bonus to any exercise (a joke statistics summary, a Disney quiz).
# - Pick an API from the [Public APIs list](https://github.com/public-apis/public-apis) and build your own mini-project following this structure.
