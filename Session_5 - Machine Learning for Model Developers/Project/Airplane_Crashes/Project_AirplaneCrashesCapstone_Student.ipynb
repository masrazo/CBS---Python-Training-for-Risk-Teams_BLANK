# %% [markdown]
# <center>
#     <img src="https://rockborne.com/wp-content/uploads/2021/07/LandingPage-Header-RED-CENTRE.jpg" width="900" alt="logo"  />
# </center>

# %% [markdown]
# # Airplane Crash Fatalities (Student)
#
# *Project · Student version*

# %% [markdown]
# ## About this project
#
# Predict `Fatalities` (a regression task) on `airplane_crashes_data.csv`, then predict for `airplane_crashes_unseen.csv` and submit `name_surname_airplane_crashes.csv` (one column `Predictions`). See `Project_Brief_AirplaneCrashes.md` for the rules. This dataset needs **a lot of preprocessing** (text dates, free-text fields, high-cardinality columns, missing values), so plan your feature engineering. The leaderboard metric is **RMSE** (lower is better). Data is in `../../../datasets/Session_5/projects_datasets/`.

# %% [markdown]
# ## 1. Setup and load
# Import your libraries and load `../../../datasets/Session_5/projects_datasets/airplane_crashes_data.csv`. It is also available on the public S3 bucket at `https://rockborne-bucket-01-cbs.s3.eu-west-2.amazonaws.com/Data_Sources_CBS_Risk/Session_5/projects_datasets/airplane_crashes_data.csv`. Take a first look.

# %%
# Your work here

# %% [markdown]
# ## 2. Data quality
# Assess the mess: missing values per column, which fields are free text or very high cardinality, and how many rows lack the target `Fatalities`. Decide what to keep and what to drop.

# %%
# Your work here

# %% [markdown]
# ## 3. Feature engineering
# Build a model-ready feature set: parse useful signal from `Date` (for example the year), decide how to handle `Operator`/`Type`, keep strong predictors like `Aboard`, and drop the text/identifier columns. A reusable function is a good idea so you can apply the same steps to the unseen data.

# %%
# Your work here

# %% [markdown]
# ## 4. EDA
# Explore the target and its drivers (for example `Aboard` vs `Fatalities`, fatalities over time). Use clear visualisations.

# %%
# Your work here

# %% [markdown]
# ## 5. Preprocessing and models
# Impute and scale as needed inside a pipeline. Train and compare at least two regression models. Report R-squared, RMSE, MSE and MAE.

# %%
# Your work here

# %% [markdown]
# ## 6. Predict the unseen set
# Apply the same feature engineering to `airplane_crashes_unseen.csv` and export `name_surname_airplane_crashes.csv` (one column `Predictions`). Remember fatalities cannot be negative.

# %%
# Your work here

# %% [markdown]
# ## Challenge (optional): mine the `Summary` free text
#
# `Summary` is a free-text narrative of each crash. You dropped it because models need numbers, but it may hold signal (words like "exploded", "collision", "engine failure", "sea").
#
# **Challenge:** turn `Summary` into numeric features and test whether they improve your regression. Techniques to try:
#
# - **Bag of words** (`CountVectorizer`) or **TF-IDF** (`TfidfVectorizer`) to vectorise the text.
# - **Stemming / lemmatisation** (e.g. NLTK) to collapse word variants before vectorising.
# - **stop-word removal, n-grams, `max_features`** to keep the vocabulary manageable.
#
# Combine the text features with your numeric features (a `ColumnTransformer` is handy), compare the held-out RMSE with and without them, and remember to apply the same fitted vectoriser to the unseen set.

# %%
# Your work here

# %% [markdown]
# ## 7. Conclusions
# Summarise your findings, the model you would use, the key drivers, your decisions/assumptions, and future work.

# %%
# Your work here
